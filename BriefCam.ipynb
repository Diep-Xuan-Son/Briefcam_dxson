# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
# os.chdir('/content/drive/MyDrive/')

# %%
cd /content/drive/MyDrive/BriefCam/BRIEFCAM_V2
# Out:
# /content/drive/MyDrive/BriefCam/BRIEFCAM_V2

# %%
# !pip install filterpy

# %%
# %cd /content/drive/MyDrive/BRIEFCAM
# !pip install -r requirements.txt

# %%
# %cd /content/drive/MyDrive/BRIEFCAM
# !rm -rf /content/drive/MyDrive/BriefCam/BRIEFCAM_V2/result
# !mkdir /content/drive/MyDrive/BriefCam/BRIEFCAM_V2/result
# !python processing_person.py --input /content/drive/MyDrive/BriefCam/BRIEFCAM_V2/video_test/test2.mkv --weights ./weights/yolov5s.pt --output /content/drive/MyDrive/BriefCam/BRIEFCAM_V2/result
# Out:
# Duong dan model thuoc tinh la: ./weights/person_mobilenet_tru_nen_xanh_v1.pth
# Resume model from ./weights/person_mobilenet_tru_nen_xanh_v1.pth
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Loaded model in 4.40 s
# [matroska,webm @ 0x64b0000] 0x00 at pos 91 (0x5b) invalid as first byte of an EBML number
# [matroska,webm @ 0x64b0000] 0x00 at pos 119 (0x77) invalid as first byte of an EBML number
# [matroska,webm @ 0x64b0000] 0x00 at pos 147 (0x93) invalid as first byte of an EBML number
# [matroska,webm @ 0x64b0000] Duplicate element
# [matroska,webm @ 0x64b0000] Duplicate element
# /content/drive/MyDrive/BriefCam/BRIEFCAM_V2/video_test/test2.mkv
# fps của video gốc là: 25.0
# Phuong fix class = 0
# Processing in frame number 100 , FPS: 30.028302165059785
# Processing in frame number 200 , FPS: 19.838272097276732
# Processing in frame number 300 , FPS: 37.720276428637355
# Processing in frame number 400 , FPS: 29.55933270308768
# ...

# %%
# !python ./RENDER_V1/render.py --data_input ./result --video_output_path ./video_brief
# Out:
# thông số video là: {'name': 'test2', 'fps': 25, 'width': 1280, 'height': 720, 'hop': 1, 'frame_total': 2700}
# Phương comment phục vụ render cho TraDeS
# tiếp tục chạy
# Đã render xong
